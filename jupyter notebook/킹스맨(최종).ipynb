# %% [markdown]
# # 훈련 과정(완료 상태)

# %%
# !pip install --upgrade transformers tensorflow-intel trio sniffio
# Out:
# ...
#   Obtaining dependency information for transformers from https://files.pythonhosted.org/packages/85/f6/c5065913119c41ecad148c34e3a861f719e16b89a522287213698da911fc/transformers-4.37.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/129.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/129.4 kB ? eta -:--:--
#      ------------------------ -------------- 81.9/129.4 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 129.4/129.4 kB 1.9 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for tensorflow-intel from https://files.pythonhosted.org/packages/4c/48/1a5a15517f18eaa4ff8d598b1c000300b20c1bb0e624539d702117a0c369/tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# ...

# %%
# !pip install ultralytics==8.0.196 
# 초기 실행시 설치 -> 컴퓨터 당 한번만

# %%
# !pip install --upgrade torch==2.1.1+cu118
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.1.1+cu118 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0)
# ERROR: No matching distribution found for torch==2.1.1+cu118

# %%
# !pip install --force-reinstall torchaudio
# Out:
# ...
#   Obtaining dependency information for torchaudio from https://files.pythonhosted.org/packages/07/1f/ddc210fc946855233d9be29d6509fb0c06803416b500a6ae7414f2371edb/torchaudio-2.2.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for torch==2.2.0 from https://files.pythonhosted.org/packages/58/b8/51b956c2da9729390a3080397cd2f31171394543af7746681466e372f69a/torch-2.2.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# ...

# %%
# !pip install fastapi kaleido python-multipart uvicorn 
# 초기 실행시 설치 -> 컴퓨터 당 한번만

# %%
# !pip install roboflow 
# 초기 실행시 설치 -> 컴퓨터 당 한번만
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/ae/bb/d95a8fe5470655a0f3051044040c2096f85658a327afecb42f715e4d1090/roboflow-1.1.19-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for certifi==2023.7.22 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB 1.5 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for opencv-python-headless==4.8.0.74 from https://files.pythonhosted.org/packages/60/e7/a6dedca760db7a4686fd3b6053487ad4ad4d8f0591295dc8a9cf35269c42/opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl.metadata
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TH0F3n2BhPtyv0Dvga8h")
project = rf.workspace("study-dxmgr").project("towel_count")
dataset = project.version(3).download("yolov8")

# %%
# 훈련 
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data='./Towel_count-3/data.yaml', epochs=30, imgsz=640)

# %% [markdown]
# # 모델 사용

# %%
from flask import Flask, request, jsonify
from flask_cors import CORS
from ultralytics import YOLO
import os
import werkzeug
import threading
app = Flask(__name__)
CORS(app)  # CORS 적용

app.config['UPLOAD_FOLDER'] = './uploads'

# 모델 불러오기
best_model = YOLO('./data/runs/detect/train2/weights/best.pt')

@app.route('/', methods=['POST'])
def predict():
    print("predict 함수 실행")
    imagefile = request.files['image']
    filename = werkzeug.utils.secure_filename(imagefile.filename)
    filepath = os.path.join(app.config['UPLOAD_FOLDER'], filename)
    imagefile.save(filepath)

    # 예측시키기
    results = best_model(filepath, save=True, conf=0.3)

    # 예측 결과 저장을 위한 리스트
    predictions = []

    for result in results:
        for box in result.boxes:
            class_name = result.names[int(box.cls[0])]
            predictions.append({
                'class': class_name,
                'message': '50개 입니다.' if class_name == '50_towel_counts' else '50개가 아닙니다.'
            })

    # 예측 결과가 없을 경우 오류 메시지 반환
    if not predictions:
        return jsonify({
            'error': 'No valid class found.'
        }), 400

    # 예측 결과 반환
    return jsonify(predictions), 200

if __name__ == "__main__":
    app.run(debug=True)
# 별도의 스레드에서 Flask 앱 실행
#def run_app(app):
#    app.run(use_reloader=False)  # reloader를 비활성화

#threading.Thread(target=run_app, args=(app,)).start()
